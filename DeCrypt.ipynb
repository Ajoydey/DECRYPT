# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajoydey/DECRYPT/blob/main/DeCrypt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
 
import matplotlib.pylab as plt
 
 
# Initial permut matrix for the datas
PI = [58, 50, 42, 34, 26, 18, 10, 2,
      60, 52, 44, 36, 28, 20, 12, 4,
      62, 54, 46, 38, 30, 22, 14, 6,
      64, 56, 48, 40, 32, 24, 16, 8,
      57, 49, 41, 33, 25, 17, 9, 1,
      59, 51, 43, 35, 27, 19, 11, 3,
      61, 53, 45, 37, 29, 21, 13, 5,
      63, 55, 47, 39, 31, 23, 15, 7]
 
print(len(PI))
 
# Initial permut made on the key and drop all multiple of 8th bit
CP_1 = [57, 49, 41, 33, 25, 17, 9, 1,
        58, 50, 42, 34, 26, 18, 10, 2,
        59, 51, 43, 35, 27, 19, 11, 3,
        60, 52, 44, 36, 63, 55, 47, 39,
        31, 23, 15, 7, 62, 54, 46, 38,
        30, 22, 14, 6, 61, 53, 45, 37,
        29, 21, 13, 5, 28, 20, 12, 4,
        121, 113, 105, 97, 89, 81, 73, 65,
        122, 114, 106, 98, 90, 82, 74, 66,
        123, 115, 107, 99, 91, 83, 75, 67,
        124, 116, 108, 100, 127, 119, 111, 103,
        95, 87, 79, 71, 126, 118, 110, 102,
        94, 86, 78, 70, 125, 117, 109, 101,
        93, 85, 77, 69, 92, 84, 76, 68,
        185, 177, 169, 161, 153, 145, 137,
        129, 186, 178, 170, 162, 154, 146,
        138, 130, 187, 179, 171, 163, 155,
        147, 139, 131, 188, 180, 172, 164,
        191, 183, 175, 167, 159, 151, 143,
        135, 190, 182, 174, 166, 158, 150,
        142, 134, 189, 181, 173, 165, 157,
        149, 141, 133, 156, 148, 140, 132]
print(len(CP_1))
# Permut applied on shifted key to get Ki+1
CP_2 = [14, 17, 11, 24, 1, 5, 3, 28,
        15, 6, 21, 10, 23, 19, 12, 4,
        26, 8, 16, 7, 27, 20, 13, 2,
        41, 52, 31, 37, 47, 55, 30, 40,
        51, 45, 33, 48, 44, 49, 39, 56,
        34, 53, 46, 42, 50, 36, 29, 32,
        70, 73, 67, 80, 57, 61, 59, 84,
        71, 62, 77, 66, 79, 75, 68, 60,
        82, 64, 72, 63, 83, 76, 69, 58,
        97, 108, 87, 93, 103, 111, 86, 96,
        107, 101, 89, 104, 100, 105, 95, 112,
        90, 109, 102, 98, 106, 92, 85, 88,
        126, 129, 122, 136, 113, 117, 115, 140,
        127, 118, 133, 122, 135, 131, 124, 116,
        138, 120, 128, 119, 139, 132, 125, 114,
        153, 164, 143, 149, 159, 167, 142, 152,
        163, 157, 145, 160, 156, 161, 151, 168,
        146, 165, 158, 154, 162, 148, 141, 144]
 
# Expand matrix to get a 48bits matrix of datas to apply the xor with Ki
E = [32, 1, 2, 3, 4, 5,
     4, 5, 6, 7, 8, 9,
     8, 9, 10, 11, 12, 13,
     12, 13, 14, 15, 16, 17,
     16, 17, 18, 19, 20, 21,
     20, 21, 22, 23, 24, 25,
     24, 25, 26, 27, 28, 29,
     28, 29, 30, 31, 32, 1]
 
# SBOX
S_BOX = [
 
    [[14, 4, 13, 1, 2, 15, 11, 8, 3, 10, 6, 12, 5, 9, 0, 7],
     [0, 15, 7, 4, 14, 2, 13, 1, 10, 6, 12, 11, 9, 5, 3, 8],
     [4, 1, 14, 8, 13, 6, 2, 11, 15, 12, 9, 7, 3, 10, 5, 0],
     [15, 12, 8, 2, 4, 9, 1, 7, 5, 11, 3, 14, 10, 0, 6, 13],
     ],
 
    [[15, 1, 8, 14, 6, 11, 3, 4, 9, 7, 2, 13, 12, 0, 5, 10],
     [3, 13, 4, 7, 15, 2, 8, 14, 12, 0, 1, 10, 6, 9, 11, 5],
     [0, 14, 7, 11, 10, 4, 13, 1, 5, 8, 12, 6, 9, 3, 2, 15],
     [13, 8, 10, 1, 3, 15, 4, 2, 11, 6, 7, 12, 0, 5, 14, 9],
     ],
 
    [[10, 0, 9, 14, 6, 3, 15, 5, 1, 13, 12, 7, 11, 4, 2, 8],
     [13, 7, 0, 9, 3, 4, 6, 10, 2, 8, 5, 14, 12, 11, 15, 1],
     [13, 6, 4, 9, 8, 15, 3, 0, 11, 1, 2, 12, 5, 10, 14, 7],
     [1, 10, 13, 0, 6, 9, 8, 7, 4, 15, 14, 3, 11, 5, 2, 12],
     ],
 
    [[7, 13, 14, 3, 0, 6, 9, 10, 1, 2, 8, 5, 11, 12, 4, 15],
     [13, 8, 11, 5, 6, 15, 0, 3, 4, 7, 2, 12, 1, 10, 14, 9],
     [10, 6, 9, 0, 12, 11, 7, 13, 15, 1, 3, 14, 5, 2, 8, 4],
     [3, 15, 0, 6, 10, 1, 13, 8, 9, 4, 5, 11, 12, 7, 2, 14],
     ],
 
    [[2, 12, 4, 1, 7, 10, 11, 6, 8, 5, 3, 15, 13, 0, 14, 9],
     [14, 11, 2, 12, 4, 7, 13, 1, 5, 0, 15, 10, 3, 9, 8, 6],
     [4, 2, 1, 11, 10, 13, 7, 8, 15, 9, 12, 5, 6, 3, 0, 14],
     [11, 8, 12, 7, 1, 14, 2, 13, 6, 15, 0, 9, 10, 4, 5, 3],
     ],
 
    [[12, 1, 10, 15, 9, 2, 6, 8, 0, 13, 3, 4, 14, 7, 5, 11],
     [10, 15, 4, 2, 7, 12, 9, 5, 6, 1, 13, 14, 0, 11, 3, 8],
     [9, 14, 15, 5, 2, 8, 12, 3, 7, 0, 4, 10, 1, 13, 11, 6],
     [4, 3, 2, 12, 9, 5, 15, 10, 11, 14, 1, 7, 6, 0, 8, 13],
     ],
 
    [[4, 11, 2, 14, 15, 0, 8, 13, 3, 12, 9, 7, 5, 10, 6, 1],
     [13, 0, 11, 7, 4, 9, 1, 10, 14, 3, 5, 12, 2, 15, 8, 6],
     [1, 4, 11, 13, 12, 3, 7, 14, 10, 15, 6, 8, 0, 5, 9, 2],
     [6, 11, 13, 8, 1, 4, 10, 7, 9, 5, 0, 15, 14, 2, 3, 12],
     ],
 
    [[13, 2, 8, 4, 6, 15, 11, 1, 10, 9, 3, 14, 5, 0, 12, 7],
     [1, 15, 13, 8, 10, 3, 7, 4, 12, 5, 6, 11, 0, 14, 9, 2],
     [7, 11, 4, 1, 9, 12, 14, 2, 0, 6, 10, 13, 15, 3, 5, 8],
     [2, 1, 14, 7, 4, 10, 8, 13, 15, 12, 9, 0, 3, 5, 6, 11],
     ]
]
 
# Permut made after each SBox substitution for each round
P = [16, 7, 20, 21, 29, 12, 28, 17,
     1, 15, 23, 26, 5, 18, 31, 10,
     2, 8, 24, 14, 32, 27, 3, 9,
     19, 13, 30, 6, 22, 11, 4, 25]
 
# Final permut for datas after the 16 rounds
PI_1 = [40, 8, 48, 16, 56, 24, 64, 32,
        39, 7, 47, 15, 55, 23, 63, 31,
        38, 6, 46, 14, 54, 22, 62, 30,
        37, 5, 45, 13, 53, 21, 61, 29,
        36, 4, 44, 12, 52, 20, 60, 28,
        35, 3, 43, 11, 51, 19, 59, 27,
        34, 2, 42, 10, 50, 18, 58, 26,
        33, 1, 41, 9, 49, 17, 57, 25]
 
PI_1_tmp = [40, 8, 48, 16, 56, 24, 64, 32,
            39, 7, 47, 15, 55, 23, 63, 31,
            38, 6, 46, 14, 54, 22, 62, 30,
            37, 5, 45, 13, 53, 21, 61, 29,
            36, 4, 44, 12, 52, 20, 60, 28,
            35, 3, 43, 11, 51, 19, 59, 27,
            34, 2, 42, 10, 50, 18, 58, 26,
            33, 1, 41, 9, 49, 17, 57, 25]
 
# Matrix that determine the shift for each round of keys
SHIFT = [1, 1, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 1]
 
 
def string_to_bit_array(text):  # Convert a string into a list of bits
    array = list()
    for char in text:
        binval = binvalue(char, 8)  # Get the char value on one byte
        array.extend([int(x) for x in list(binval)])  # Add the bits to the final list
    return array
 
 
def bit_array_to_string(array):  # Recreate the string from the bit array
    res = ''.join([chr(int(y, 2)) for y in [''.join([str(x) for x in _bytes]) for _bytes in nsplit(array, 8)]])
    return res
 
 
def binvalue(val, bitsize):  # Return the binary value as a string of the given size
    binval = bin(val)[2:] if isinstance(val, int) else bin(ord(val))[2:]
    if len(binval) > bitsize:
        raise Exception('binary value larger than the expected size')
    while len(binval) < bitsize:
        binval = "0" + binval  # Add as many 0 as needed to get the wanted size
    return binval
 
 # Split a list into sublists of size "n"
def nsplit(s, n): 
    return [s[k:k + n] for k in range(0, len(s),n)]
 
ENCRYPT = 1
DECRYPT = 0
 
 
class TestFailed(Exception):
    def __init__(self, m):
        self.message = m
 
 
class des():
    def __init__(self):
        self.password = None
        self.text = None
        self.keys = list()
        self.padding = None
 
    def run(self, key, text, padding, action=ENCRYPT):
        if len(key) < 24:
            try:
                raise TestFailed("Key Should be 24 bytes long")
            except TestFailed as exp:
                print(exp)
 
        elif len(key) > 24:
            key = key[:24]  # If key size is above 24 bytes, cut to be 24 bytes long
 
        self.password = key
        self.text = text
        if len(self.text) % 24 != 0:
            padding = True
        if padding and action == ENCRYPT:
            self.addPadding()
 
        self.generatekeys()  # Generate all the keys
        text_blocks = string_to_bit_array(self.text)  # convert into bit array
        text_blocks = nsplit(text_blocks, 192)  # Split the text in blocks of 192 bits
        temp_result = list()
        result = list()
        count = 0
        for block in text_blocks:  # Loop over all the blocks of data
            g, m, d = nsplit(block, 64)
            g = self.permut(g, PI)  # Apply the initial permutation
            m = self.permut(m, PI)
            d = self.permut(d, PI)
            # g(LEFT),m(MIDDLE) d(RIGHT)
 
            block_g_l, block_g_r = nsplit(g, 32)
            block_m_l, block_m_r = nsplit(m, 32)
            block_d_l, block_d_r = nsplit(d, 32)
            tmp = None
            s_tmp = None
            t_tmp = None
            
            #Feistel 

            for i in range(16):  # Do the 16 rounds
                block_g_r_e = self.expand(block_g_r, E)  # Expand d to match Ki size (48bits)
                block_m_r_e = self.expand(block_m_r, E)
                block_d_r_e = self.expand(block_d_r, E)
                if action == ENCRYPT:
                    key, s_key, t_key = nsplit(self.keys[i], 48)
                    tmp = self.xor(key, block_g_r_e)  
                    s_tmp = self.xor(s_key, block_m_r_e)
                    t_tmp = self.xor(t_key, block_d_r_e)
                else:    #decryption process
                    key, s_key, t_key = nsplit(self.keys[15 - i], 48)
                    if i % 3 == 0:
                        tmp = self.xor(key, block_g_r_e)
                        s_tmp = self.xor(s_key, block_m_r_e)
                        t_tmp = self.xor(t_key, block_d_r_e)
                    elif i % 3 == 1:
                        tmp = self.xor(t_key, block_g_r_e)
                        s_tmp = self.xor(key, block_m_r_e)
                        t_tmp = self.xor(s_key, block_d_r_e)
                    else:
                        tmp = self.xor(s_key, block_g_r_e)
                        s_tmp = self.xor(t_key, block_m_r_e)
                        t_tmp = self.xor(key, block_d_r_e)
                
                #Method that will apply the SBOXes

                tmp = self.substitute(tmp) 
                s_tmp = self.substitute(s_tmp)
                t_tmp = self.substitute(t_tmp)
                tmp = self.permut(tmp, P)
                s_tmp = self.permut(s_tmp, P)
                t_tmp = self.permut(t_tmp, P)
                tmp = self.xor(block_g_l, tmp)
                s_tmp = self.xor(block_m_l, s_tmp)
                t_tmp = self.xor(block_d_l, t_tmp)
 
                #interchange

                block_g_l = block_d_r
                block_m_l = block_g_r
                block_d_l = block_m_r
                block_g_r = tmp
                block_m_r = s_tmp
                block_d_r = t_tmp
 
            # Do the last permut and append the result to result after first encryption
            result += self.permut(block_g_r + block_m_l, PI_1) + self.permut(block_m_r + block_d_l, PI_1) + self.permut(block_d_r + block_g_l,PI_1)  
            count += 1
        final_res = bit_array_to_string(result)
        if padding and action == DECRYPT:
            return self.removePadding(final_res)  # Remove the padding if decrypt and padding is true
        else:
            return final_res  # Return the final string of data ciphered/deciphered
 
    def substitute(self, block_g_l_e):  # Substitute bytes using SBOX
        subblocks = nsplit(block_g_l_e, 6)  # Split bit array into sublist of 6 bits
        result = list()
        for i in range(len(subblocks)):  # For all the sublists
            block = subblocks[i]
            row = int(str(block[0]) + str(block[5]), 2)  # Get the row with the first and last bit
            column = int(''.join([str(x) for x in block[1:][:-1]]), 2)  # Column is the 2,3,4,5th bits
            val = S_BOX[i][row][column]  # Take the value in the SBOX appropriated for the round (i)
            bin = binvalue(val, 4)  # Convert the value to binary
            result += [int(x) for x in bin]  # And append it to the resulting list
        return result
 
    def permut(self, block, table):  # Permut the given block using the given table (so generic method)
        return [block[x - 1] for x in table]
 
    def expand(self, block, table):  # Do the exact same thing than permut but for more clarity has been renamed
        return [block[x - 1] for x in table]
 
    def xor(self, t1, t2):  # Apply a xor and return the resulting list
        return [x ^ y for x, y in zip(t1, t2)]
 
    def generatekeys(self):  # Algorithm that generates all the keys
        self.keys = []
        key = string_to_bit_array(self.password)
        key = key[:192]
        key = self.permut(key, CP_1)  # Apply the initial permut on the key
        g, m, d = nsplit(key, 56)  # split key into 3 parts
        g_l, g_r = nsplit(g,28)
        m_l, m_r = nsplit(g,28)
        d_l, d_r = nsplit(g,28)
        for i in range(16):  # Apply the 16 rounds
            g_l, g_r = self.shift(g_l, g_r, SHIFT[i])
            m_l, m_r = self.shift(m_l, m_r, SHIFT[i])
            d_l, d_r = self.shift(d_l, d_r, SHIFT[i])
            self.keys.append(self.permut(g_l + g_r + m_l + m_r + d_l + d_r, CP_2))  # Apply the permut to get the Ki
 
    def shift(self, g, d, n): #Shift a list of the given value
        return g[n:] + g[:n], d[n:] + d[:n]
 
    def addPadding(self):  # Add padding to the datas using PKCS5 spec.
        pad_len = 24 - (len(self.text) % 24)
        #print(pad_len)
        self.text += pad_len * chr(pad_len)
 
    def removePadding(self, data):  # Remove the padding of the plain text (it assume there is padding)
        pad_len = ord(data[-1])
        return data[:-pad_len]
 
    def encrypt(self, key, text, padding):
        return self.run(key, text, padding, ENCRYPT)
 
    def decrypt(self, key, text, padding):
        return self.run(key, text, padding, DECRYPT)
 
 
if __name__ == '__main__':
    key = "holaholaholaholaholaholaholahola"
    text = "A quick brown fox jumps over a lazy dog. Cryptograph"
    padding = False
    if len(text) % 24 != 0:
        padding = True
    d = des()
    t0 = time.perf_counter()
    r = d.encrypt(key, text, padding)
    t1 = time.perf_counter()
    encription_time = t1 - t0
    print("Ciphered: %r" % r )
    print("Encryption time",encription_time)
    t0 = time.perf_counter()
    r2 = d.decrypt(key, r, padding)
    t1 = time.perf_counter()
    decription_time = t1 - t0
    print("Deciphered: %r " % r2)
    print("Decryption time",decription_time)
# Out:
# 64
# 168
# Ciphered: ']´´\x89{¬q\x99¯¥2]kì»¿wo×\nÚWCJ´(K¾vó\x95+´\x1bC\x1fÖ²+4EÈ Ú!Ù×4$ù\x17Ee#£\x10\x19#Lny\x06O\x0f\x10Ç\x06\x8c\x8dc%\x85'
# Encryption time 0.010997083999995994
# Deciphered: 'A quick brown fox jumps over a lazy dog. Cryptograph'
# Decryption time 0.010226458999994748
